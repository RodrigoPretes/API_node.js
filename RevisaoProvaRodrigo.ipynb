# %% [markdown]
# <a href="https://colab.research.google.com/github/RodrigoPretes/API_node.js/blob/main/RevisaoProvaRodrigo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Questão1**

# %%
# !pip install numpy
# !pip install matplotlib
# !pip install tensorflow
# !pip install scikeras
import tensorflow as tf
print(tf.__version__)
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree # Adicionei a importação correta para
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Out:
# ...
# 2.14.0

# %%
# Entrada de dados
X = np.array(
 [
 ['M', 'T', 'F'],
 ['M', 'T', 'T'],
 ['F', 'T', 'T'],
 ['M', 'F', 'T'],
 ['F', 'T', 'F'],
 ['M', 'F', 'F'],
 ['F', 'F', 'T']
 ]
)
Y = np.array( [ 'Sim', 'Sim', 'Não', 'Não',
'Não', 'Não', 'Não'] )
X1 = pd.DataFrame(X, dtype=str, columns=['Sexo',
'Idade<26', 'Tem carro'])
XX = pd.get_dummies(data=X1, columns=['Sexo',
'Idade<26', 'Tem carro'])
XX
Y1 = pd.DataFrame(Y, dtype=str, columns=['É assinante?'])
YY = pd.get_dummies(data=Y1, columns=['É assinante?'])
YY
# Out:
#    É assinante?_Não  É assinante?_Sim
# 0                 0                 1
# 1                 0                 1
# 2                 1                 0
# 3                 1                 0
# 4                 1                 0
# 5                 1                 0
# 6                 1                 0

# %%
# Criando o classificador
arvore = DecisionTreeClassifier(criterion='entropy',
max_depth=2)

# %%
# Criando a árvore
arvore = arvore.fit(XX, YY)
arvore.feature_importances_
arvore.classes_
arvore.score(XX, YY)
# Out:
# 1.0

# %%
# Visualizando essa árvore
from sklearn import tree
fig, ax = plt.subplots(figsize=(10,8))
tree.plot_tree(arvore)
plt.show()
# Visualizando essa árvore 2
figura, eixos = plt.subplots(nrows=1, ncols=1,
figsize=(10,10))
tree.plot_tree(arvore, feature_names=XX.columns,
class_names = ['Não', 'Sim'], filled=True)
# Out:
# [Text(0.6, 0.8333333333333334, 'Sexo_F <= 0.5\nentropy = 0.863\nsamples = 7\nvalue = [[2, 5]\n[5, 2]]'),
#  Text(0.4, 0.5, 'Idade<26_T <= 0.5\nentropy = 1.0\nsamples = 4\nvalue = [[2, 2]\n[2, 2]]'),
#  Text(0.2, 0.16666666666666666, 'entropy = 0.0\nsamples = 2\nvalue = [[0, 2]\n[2, 0]]'),
#  Text(0.6, 0.16666666666666666, 'entropy = 0.0\nsamples = 2\nvalue = [[2, 0]\n[0, 2]]'),
#  Text(0.8, 0.5, 'entropy = 0.0\nsamples = 3\nvalue = [[0, 3]\n[3, 0]]')]

# %%
# Regra Se- Então
from sklearn.tree import export_text
XX.columns
r = export_text(arvore, feature_names=['Sexo_M',
'Sexo_F', 'Idade<26_T', 'Idade<26_F',
'Tem Carro_F', 'Tem Carro_T'])
print(r)
# Out:
# |--- Sexo_M <= 0.50
# |   |--- Idade<26_F <= 0.50
# |   |   |--- class: 1
# |   |--- Idade<26_F >  0.50
# |   |   |--- class: 0
# |--- Sexo_M >  0.50
# |   |--- class: 1

# %% [markdown]
# **Questão2**

# %%
# !pip install geneticalgorithm


# !pip install numpy
# !pip install matplotlib
# !pip install tensorflow
import tensorflow as tf
print(tf.__version__)
import keras
import pandas as pd
import numpy as np
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for func-timeout: filename=func_timeout-4.3.5-py3-none-any.whl size=15080 sha256=ff3583da5ec19915534bbb10379fb6963451d5a475427032d44e6673027ad8f7
#   Stored in directory: /root/.cache/pip/wheels/3f/83/19/b5552bb9630e353f7c5b15be44bf10900afe1abbbfcf536afd
# Successfully built func-timeout
# ...
# 2.14.0

# %%
import tensorflow as tf
print(tf.__version__)

import keras
import pandas as pd
import numpy as np

# import warnings
# warnings.filterwarnings('ignore')



# Entra com os dados
X_treino = np.array(
    [
        [350,6], [200,3], [180,4], [400,7], [380,8],
        [410,7], [220,2], [190,3]
    ]
)
Y_treino = np.array( [ #-1 laranja / # 1 limao
         [-1],[1],[1],[-1],[-1],
         [-1],[1],[1] ] )
X_teste = np.array(
    [
        [390,8], [160,3]
    ]
)
Y_teste = np.array( [[1],[-1]] )




# Monta a rede
from keras.models import Sequential
from keras.layers import Dense

modelo = Sequential() # Inicializa a Rede Neural Artificial

modelo.add(Dense(units = 1, input_dim = X_treino.shape[1]))



# Mostra a rede
modelo.summary()



# Treina a rede
modelo.compile(loss='mae', optimizer = 'adam', metrics=['mae'])


resultado = modelo.fit(X_treino, Y_treino, batch_size = 13, epochs = 2000, validation_data=(X_teste, Y_teste))



# Mostra o Teste
Y_predito = modelo.predict(X_teste)

Y_predito





# Teste da Rede
Y_predito = modelo.predict(X_teste) # Faz o arrendodamento
Y_predito = [ 1 if y>=0.0 else -1 for y in Y_predito ] #positivo +1 / negativo -1
print("Valores Preditos:",Y_predito)

total = 0
correto = 0
errado = 0
for i in Y_predito:
  total=total+1
  if(Y_teste[i,0] == Y_predito[i]):
    correto=correto+1
  else:
    errado=errado+1

print("Total " + str(total))
print("Correto " + str(correto))
print("Errado " + str(errado))



# Mostra graficos
import matplotlib.pyplot as plt

plt.plot(resultado.history['loss'])
plt.plot(resultado.history['val_loss'])
plt.title('Histórico de Treinamento')
plt.ylabel('Função de custo')
plt.xlabel('Épocas de treinamento')
plt.legend(['Erro treino', 'Erro teste'])
plt.show()





# Mostra Pesos
for layerNum, layer in enumerate(modelo.layers):
    weights = layer.get_weights()[0]
    biases = layer.get_weights()[1]

    for toNeuronNum, bias in enumerate(biases):
        print(f'{layerNum}B -> L{layerNum+1}N{toNeuronNum}: {bias}')

    for fromNeuronNum, wgt in enumerate(weights):
        for toNeuronNum, wgt2 in enumerate(wgt):
            print(f'L{layerNum}N{fromNeuronNum} \
                  -> L{layerNum+1}N{toNeuronNum} = {wgt2}')
# Out:
# 2.14.0
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_1 (Dense)             (None, 1)                 3
#
# ...
# Total params: 3 (12.00 Byte)
# Trainable params: 3 (12.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/2000
# 1/1 [==============================] - 1s 822ms/step - loss: 351.2042 - mae: 351.2042 - val_loss: 332.2811 - val_mae: 332.2811
# Epoch 2/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 350.9070 - mae: 350.9070 - val_loss: 331.9996 - val_mae: 331.9996
# Epoch 3/2000
# 1/1 [==============================] - 0s 71ms/step - loss: 350.6097 - mae: 350.6097 - val_loss: 331.7181 - val_mae: 331.7181
# Epoch 4/2000
# 1/1 [==============================] - 0s 47ms/step - loss: 350.3124 - mae: 350.3124 - val_loss: 331.4366 - val_mae: 331.4366
# Epoch 5/2000
# ...

# %% [markdown]
# **Questão 3**
#
# 1
#
#
# 1
#
#
# 1
#
#
# 0,8
#
#
# 0,5
#
#
# 0,2
#
#
# 0
#
#
# 0

# %%
# !pip install scikit-fuzzy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 kB 11.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894078 sha256=d4be70ed18bc08e41528ab4608e3397ea7ff5218d749e4796604e40d9b1298b0
#   Stored in directory: /root/.cache/pip/wheels/4f/86/1b/dfd97134a2c8313e519bcebd95d3fedc7be7944db022094bc8
# Successfully built scikit-fuzzy
# ...

# %%
# [2] Fuzzificação
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# %%
# Criando as variáveis do problema
altura = ctrl.Antecedent(np.arange(120,180,1),'altura')

# %%
# Criando as funções de pertinência para a altura
altura['Baixo']= fuzz.trapmf(altura.universe,[120,140,140,150])

altura.view()

# %% [markdown]
# [Valor, Grau] (129, 1) (138, 1) (140, 1) (142, 1) (145, 1) (148, 1) (150, 0) (154, 0)

# %%
altura['Medio']= fuzz.trimf(altura.universe,[150,170,180])

altura.view()

# %%
[Valor,  Grau]
(152,    0)
(153,    0)
(158,    0)
(162,    1)
(170,    1)
(173,    1)
(180,    1)

# %% [markdown]
# **Questão4**

# %%
# Criando as variáveis do problema
valor1 = ctrl.Antecedent(np.arange(0,1,0.1),'valor1')
valor2 = ctrl.Antecedent(np.arange(0,0.9,0.1),'valor2')
And = ctrl.Consequent(np.arange(0,1,0.1),'And')
Or = ctrl.Consequent(np.arange(0,1,0.1),'Or')

# %%
# Criando as funções de pertinência para o valor 1
valor1['0']= fuzz.trapmf(valor1.universe,[0.0,0.0,0.4,0.5])
valor1['1']= fuzz.trapmf(valor1.universe,[0.4,0.5,1.0,1.0])

# %%
valor1.view()

# %%
# Criando as funções de pertinência para o valor 2

valor2['0']= fuzz.trapmf(valor2.universe,[0.0,0.0,0.3,0.5])
valor2['1']= fuzz.trapmf(valor2.universe,[0.3,0.5,0.9,0.9])

valor2.view()

# %%
And['0']= fuzz.trapmf(And.universe,[0.0,0.0,0.7,0.7])
And['1']= fuzz.trapmf(And.universe,[0.7,0.7,1.0,1.0])

And.view()

# %%
Or['0']= fuzz.trapmf(Or.universe,[0.0,0.0,0.7,0.7])
Or['1']= fuzz.trapmf(Or.universe,[0.7,0.7,1.0,1.0])

Or.view()

# %%
# Base de Conhecimento/Regras
rule1 = ctrl.Rule(valor1['0'],And['0'])
rule2 = ctrl.Rule(valor2['0'],And['0'])
rule3 = ctrl.Rule(valor1['1'] & valor2['1'],And['1'])
rule4 = ctrl.Rule(valor1['1'] | valor2['1'],Or['1'])
rule5 = ctrl.Rule(valor1['1'],Or['1'])
rule6 = ctrl.Rule(valor2['1'],Or['1'])

# %%
# Sistema Fuzzy e Simulação
validade_ctrl = ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6])
validade_simulador = ctrl.ControlSystemSimulation(validade_ctrl)

# %%
# Entranda do dinheiro
while True:
   val1 = float(input('Digite valor 1): '))
   if (val1 < 0.0 or val1 > 1.0):
      print('O valor deve estar no intervalo [0, 1]')
      continue
   validade_simulador.input['valor1'] = val1
   break

# Entrada do pessoal
while True:
    val2 = float(input('Digite valor 2): '))
    if (val2 < 0.0 or val2 > 1.0):
       print('o pessoal deve estar no intervalo [0, 1]')
       continue
    validade_simulador.input['valor2'] = val2
    break

validade_simulador.compute()
print('And é %.1F' %validade_simulador.output['And'])
print('Or é %.1F' %validade_simulador.output['Or'])
# Out:
# Digite valor 1): 0
# Digite valor 2): 1
# And é 0.3
# Or é 0.8

# %%
# Visualizando as regiões
valor1.view(sim=validade_simulador)

# %%
# Visualizando as regiões
valor2.view(sim=validade_simulador)

# %%
# Visualizando as regiões
And.view(sim=validade_simulador)

# %%
# Visualizando as regiões
Or.view(sim=validade_simulador)

# %% [markdown]
# **Questao5**

# %%
# !pip install geneticalgorithm
import numpy as np
import math
from geneticalgorithm import geneticalgorithm as ga

b = np.array([
    [0, 1, 7, 5, 3],
    [1, 0, 6, 2, 5],
    [7, 6, 0, 4, 5],
    [4, 2, 4, 0, 1],
    [3, 5, 5, 1, 0]
])

inicio=0
fim=0

def f(X):
    dim=len(X)
    OF=0
    OF+=b[inicio][math.trunc(X[0])]
    for i in range(1,dim):
      OF+=b[math.trunc(X[i-1])][math.trunc(X[i])]

    for i in range(0,dim-1):
     for j in range(i+1,dim):
       if math.trunc(X[i])==math.trunc(X[j]):
         OF+=999

    OF+=b[math.trunc(X[dim-1])][fim]
    return OF

varbound=np.array([[0,len(b)-1]]*len(b))

algorithm_param = {'max_num_iteration': 3000,\
                   'population_size':100,\
                   'mutation_probability':0.1,\
                   'elit_ratio': 0.01,\
                   'crossover_probability': 0.5,\
                   'parents_portion': 0.3,\
                   'crossover_type':'uniform',\
                   'max_iteration_without_improv':None}

model = ga(function=f, dimension=len(b), variable_type='int', variable_boundaries=varbound, algorithm_parameters=algorithm_param)
model.run()


cidade = np.array(["A", "B", "C", "D", "E"])
print(cidade[inicio])
for i in model.best_variable:
    print(cidade[math.trunc(i)])

print(cidade[fim])
# Out:
# ...
#  The best solution found:
#  [4. 2. 3. 1. 0.]
#
#  Objective function:
#  15.0
# A
# E
# C
# D
# B
# A
# A
